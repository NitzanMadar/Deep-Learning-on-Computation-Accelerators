# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/MyDrive/CS236781/Homework/hw2/hw2
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CS236781/Homework/hw2/hw2

# %%
# %ls
# Out:
#  cs236781/                          Part2_Optimization.ipynb
#  environment.lock.yml               Part3_CNNs.ipynb
#  environment.yml                    py-sbatch.sh
#  hw2/                               README.md
#  hw2_experiment.ipynb               result2/
#  imgs/                              results/
#  jupyter-lab.sh                     results1/
#  main.py                            run_all_experiments.sh
#  Miniconda3-4.5.4-Linux-x86_64.sh   tests/
#  Part0_Intro.ipynb                 'גיבוי מלפני העדכון'/
#  Part1_Backprop.ipynb

# %%
from hw2.experiments import run_experiment
from torch.optim import SGD, RMSprop
import itertools

default_args = dict(
    run_name='',
    # Training params
    bs_train=128,
    bs_test=None,
    batches=None,
    epochs=100,
    early_stopping=3,
    checkpoints=None,
    lr=1e-3,
    reg=1e-3,

    # Model params
    filters_per_layer=[64],
    layers_per_block=2,
    pool_every=2,
    hidden_dims=[1024],
    model_type="cnn",
#     pooling_params=dict(kernel_size=2),
#     model_params=dict(
#         conv_params=dict(kernel_size=3, padding=1)
#     )
)

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %%
def experiment1_4():
    args = default_args.copy()
    args['run_name'] = 'exp1_4'
    args['model_type'] = 'resnet'
    args['early_stopping'] = 9

#     Ks = [[32]]
#     Ls = [8, 16, 32]
#     for K, L in itertools.product(Ks, Ls):
#         args['filters_per_layer'] = K
#         args['layers_per_block'] = L
#         args['pool_every'] = len(K) * L // 2
#         run_experiment(**args)

    Ks = [[64, 128, 256]]
    Ls = [2, 4, 8]
#     Ls = [ 8]
    for K, L in itertools.product(Ks, Ls):
        args['filters_per_layer'] = K
        args['layers_per_block'] = L
        args['pool_every'] = len(K) * L // 2
        args['pool_every'] = 4
        run_experiment(**args)

# %%
experiment1_4()
# Out:
# ...
# test_batch (Avg. Loss 7.180, Accuracy 69.3): 100%|██████████| 313/313 [00:04<00:00, 64.69it/s]
# --- EPOCH 81/100 ---
# ...
# test_batch (Avg. Loss 7.853, Accuracy 68.5): 100%|██████████| 313/313 [00:04<00:00, 64.89it/s]
# --- EPOCH 82/100 ---
# ...
# test_batch (Avg. Loss 7.737, Accuracy 68.0): 100%|██████████| 313/313 [00:04<00:00, 64.89it/s]
# --- EPOCH 83/100 ---
# train_batch (0.000):   9%|▊         | 34/391 [00:04<00:49,  7.24it/s]

# %%
plot_exp_results('exp1_4_L*_K32.json')

# %%
plot_exp_results('exp1_4_L*_K64*.json')

# %%
def experiment1_1():
  args = default_arguments.copy()
  args['run_name']='exp1_1'
  Ks=[[32],[64]]
  Ls=[2,4,8,16]
  for K,L in itertools.product(Ks,Ls):
    
    args['model_type']='cnn'
    args['filters_per_layer']=K
    args['layers_per_block']=L
    args['pool_every']=len(K)*L//2
    experiments.run_experiment(**args)

# %%
experiment1_1()
# Out:
# ...
# Failed download. Trying https -> http instead. Downloading http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
# ...
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-89d54e4a09a3> in <module>()
# ----> 1 experiment1_1()
#
# <ipython-input-6-0d468a6dc140> in experiment1_1()
#      10     args['layers_per_block']=L
#      11     args['pool_every']=len(K)*L//2
# ---> 12     experiments.run_experiment(**args)
#
# /content/drive/MyDrive/CS236781/Homework/hw2/hw2/hw2/experiments.py in run_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, **kw)
# ...

# %%
def experiment1_4():
  args = default_arguments.copy()
  args['run_name']='exp1_4'
  Ks=[[64,128,256]]
  Ls=[2,4,8]
  for K,L in itertools.product(Ks,Ls):
    print(len(K))
    args['model_type']='resnet'
    args['filters_per_layer']=K
    args['layers_per_block']=L
    args['pool_every']=len(K)*L//2
    experiments.run_experiment(**args)

# %%
experiment1_4()
# Out:
# 3
# Files already downloaded and verified
# Files already downloaded and verified
# {}
# --- EPOCH 1/100 ---
# train_batch:   0%|          | 0/391 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-61-b889f68b7d6b> in <module>()
# ----> 1 experiment1_4()
#
# <ipython-input-60-fc5859bb91fd> in experiment1_4()
#      10     args['layers_per_block']=L
#      11     args['pool_every']=len(K)*L//2
# ---> 12     experiments.run_experiment(**args)
#
# /content/drive/My Drive/CS236781/Homework/hw2/hw2/hw2/experiments.py in run_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, **kw)
#     120     dl_train = torch.utils.data.DataLoader(ds_train, bs_train, shuffle=False)
# ...

# %%
exp_name = 'exp1_4'
kernels = [64, 128, 256]
list_layers = [2,4,8]
conv_params = dict(kernel_size=3, stride=1, padding=1)
pool_params = dict(kernel_size=3)
for layers in list_layers:
    experiments.run_experiment(
        exp_name, seed=None, bs_train=128, batches=None, epochs=100, early_stopping=3,
        filters_per_layer=kernels, layers_per_block=layers, pool_every=len(kernels)*layers//2, hidden_dims=[1024],
        model_type='resnet',
        pooling_paprams = dict(kernel_size=2)
        )
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# {'pooling_paprams': {'kernel_size': 2}}
# --- EPOCH 1/100 ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-f3f5b079aa07> in <module>()
#       9         filters_per_layer=kernels, layers_per_block=layers, pool_every=len(kernels)*layers//2, hidden_dims=[1024],
#      10         model_type='resnet',
# ---> 11         pooling_paprams = dict(kernel_size=2)
#      12         )
#
# /content/drive/My Drive/CS236781/Homework/hw2/hw2/hw2/experiments.py in run_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, **kw)
#     120     dl_train = torch.utils.data.DataLoader(ds_train, bs_train, shuffle=False)
# ...

# %%
import hw2.experiments as experiments
from hw2.experiments import load_experiment
from cs236781.plot import plot_fit

# Test experiment1 implementation on a few data samples and with a small model
experiments.run_experiment(
    'exp2', seed=None, bs_train=50, batches=10, epochs=2, early_stopping=5,
    filters_per_layer=[32,64,128], layers_per_block=3, pool_every=1, hidden_dims=[100],
    model_type='ycn',
)
cfg, fit_res = load_experiment('results/test_run_L1_K32-64.json')
_, _ = plot_fit(fit_res)

# And `cfg` contains the exact parameters to reproduce it
print('experiment config: ', cfg)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-11cf0dc33b95> in <module>()
#       7     'exp2', seed=None, bs_train=50, batches=10, epochs=2, early_stopping=5,
#       8     filters_per_layer=[32,64,128], layers_per_block=3, pool_every=1, hidden_dims=[100],
# ----> 9     model_type='ycn',
#      10 )
#      11 cfg, fit_res = load_experiment('results/test_run_L1_K32-64.json')
#
# /content/drive/MyDrive/CS236781/Homework/hw2/hw2/hw2/experiments.py in run_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, **kw)
#      93
#      94 #     model = model_cls(img_size, classes_out, channels, pool_every, hidden_dims,
# ...

# %%
from hw2.experiments import run_experiment
run_experiment("exp1_1" ,
    out_dir="./results",
    seed=None,
    device=None,
    # Training params
    bs_train=128,
    bs_test=None,
    batches=100,
    epochs=100,
    early_stopping=3,
    checkpoints=None,
    lr=1e-3,
    reg=1e-3,
    # Model params
    filters_per_layer=[32],
    layers_per_block=2,
    pool_every=2,
    hidden_dims=[1024],
    pooling_paprams = dict(kernel_size=2),
    conv_params = dict(kernel_size=3, stride=1, padding=1)
    model_type="ycn",
    # You can add extra configuration for your experiments here
)
# Out:
#   File "<ipython-input-53-840470b91a1b>", line 22
#     model_type="ycn",
#              ^
# SyntaxError: invalid syntax

# %%
# %%bash
# python -m hw2.experiments run-exp -n exp1_1 -K 32 -L 2 -P 2 -H 100 --batches 100
# Out:
# Process is terminated.

# %%
import os
os.system('run_all_experiments.sh')
# Out:
# 32512

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

# %%
# https://towardsdatascience.com/conda-google-colab-75f7c867a522

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.6.12 :: Anaconda, Inc.

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.5.4

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.54.0                |     pyhd3eb1b0_0          54 KB
#     cffi-1.14.4                |   py36h261ae71_0         224 KB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     cryptography-3.2.1         |   py36h3c74f83_1         631 KB
#     conda-4.9.2                |   py36h06a4308_0         3.1 MB
#     ------------------------------------------------------------
#                                            Total:         4.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     conda-package-handling: 1.7.2-py36h03888b9_0
#     tqdm:                   4.54.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
# ...

# %%
# !conda --version # now returns 4.8.3
# Out:
# conda 4.9.2

# %%
# !python --version # now returns Python 3.6.10 :: Anaconda, Inc.
# Out:
# Python 3.6.12 :: Anaconda, Inc.

# %%
import sys
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages
# Out:
# absl
# absl_py-0.10.0.dist-info
# alabaster
# alabaster-0.7.12.dist-info
# albumentations
# albumentations-0.1.12.dist-info
# altair
# altair-4.1.0.dist-info
# apiclient
# argon2
# argon2_cffi-20.1.0.dist-info
# asgiref
# asgiref-3.3.1.dist-info
# astor
# astor-0.8.1.dist-info
# astropy
# astropy-4.1.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# async_generator
# async_generator-1.10.dist-info
# atari_py
# atari_py-0.2.6.dist-info
# atomicwrites
# atomicwrites-1.4.0.dist-info
# attr
# attrs-20.3.0.dist-info
# audioread
# audioread-2.1.9.dist-info
# autograd
# autograd-1.3.dist-info
# babel
# Babel-2.9.0.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.6.3.dist-info
# bin
# bleach
# bleach-3.2.1.dist-info
# blis
# blis-0.4.1.dist-info
# bokeh
# bokeh-2.1.1.dist-info
# bottleneck
# Bottleneck-1.3.2.dist-info
# branca
# branca-0.4.1.dist-info
# bs4
# bs4-0.0.1.dist-info
# bson
# cachecontrol
# CacheControl-0.12.6.dist-info
# cachetools
# ...

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# %cd 'drive/MyDrive/CS236781/Homework/hw2/hw2'
# Out:
# /content/drive/MyDrive/CS236781/Homework/hw2/hw2

# %%
# %ls
# Out:
#  cs236781/                           Part0_Intro.ipynb
#  environment.lock.yml                Part1_Backprop.ipynb
#  environment.yml                     Part2_Optimization.ipynb
#  hw2/                                Part3_CNNs.ipynb
#  hw2_experiment.ipynb                py-sbatch.sh
#  imgs/                               README.md
#  jupyter-lab.sh                      tests/
#  main.py                            'גיבוי מלפני העדכון'/
#  Miniconda3-4.5.4-Linux-x86_64.sh*

# %%
 # !conda env update -f environment.yml
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ...
# pcre-8.44            |  269 KB | : 100% 1.0/1 [00:00<00:00,  5.49it/s]
# testpath-0.4.4       |   88 KB | : 100% 1.0/1 [00:00<00:00, 12.55it/s]
# requests-2.25.0      |   51 KB | : 100% 1.0/1 [00:00<00:00, 20.34it/s]
# ld_impl_linux-64-2.3 |  617 KB | : 100% 1.0/1 [00:00<00:00,  3.36it/s]
# xorg-xextproto-7.3.0 |   27 KB | : 100% 1.0/1 [00:00<00:00, 18.26it/s]
# numpy-1.19.2         |   21 KB | : 100% 1.0/1 [00:00<00:00, 28.58it/s]
# networkx-2.5         |  1.2 MB | : 100% 1.0/1 [00:00<00:00,  1.08it/s]
# jinja2-2.11.2        |   97 KB | : 100% 1.0/1 [00:00<00:00, 17.10it/s]
# murmurhash-1.0.2     |   27 KB | : 100% 1.0/1 [00:00<00:00, 25.07it/s]
# jedi-0.17.2          |  945 KB | : 100% 1.0/1 [00:00<00:00,  1.07it/s]
# pandas-1.1.3         | 10.9 MB | : 100% 1.0/1 [00:03<00:00,  3.58s/it]
# ...

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# cs236781-hw              /usr/local/envs/cs236781-hw

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.6/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.

# %%
# !source activate cs236781-hw && conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# cs236781-hw           *  /usr/local/envs/cs236781-hw

# %%
# !source /usr/local/envs/cs236781-hw
# !source activate cs236781-hw
# !conda info --envs
# Out:
# /bin/bash: line 0: source: /usr/local/envs/cs236781-hw: is a directory
# # conda environments:
# #
# base                  *  /usr/local
# cs236781-hw              /usr/local/envs/cs236781-hw

# %%
# !source activate cs236781-hw && <command...>
# !source activate cs236781-hw && bash run_all_experiments.sh
# Out:
# /bin/bash: activate: No such file or directory

# %%
# !sh run_all_experiments.sh
# run -c 2 --gres=gpu:1  --pty python -m hw2.experiments run-exp -n ${exp_name} -K $K -L $L -P $((L/2+1)) -H 100 --batches 50
from hw2.experiments import run_experiment
run_experiment("exp1_1" ,
    out_dir="./results",
    seed=None,
    device=None,
    # Training params
    bs_train=128,
    bs_test=None,
    batches=100,
    epochs=100,
    early_stopping=3,
    checkpoints=None,
    lr=1e-3,
    reg=1e-3,
    # Model params
    filters_per_layer=[32],
    layers_per_block=2,
    pool_every=2,
    hidden_dims=[1024],
    model_type="cnn",
    # You can add extra configuration for your experiments here
)
# Out:
# ...
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# ...
# test_batch (Avg. Loss 1.360, Accuracy 50.1): 100%|██████████| 313/313 [00:03<00:00, 78.94it/s]
# --- EPOCH 2/100 ---
# ...
# test_batch (Avg. Loss 1.144, Accuracy 59.3): 100%|██████████| 313/313 [00:03<00:00, 80.41it/s]
# --- EPOCH 3/100 ---
# ...
# test_batch (Avg. Loss 1.043, Accuracy 64.6): 100%|██████████| 313/313 [00:03<00:00, 80.76it/s]
# --- EPOCH 4/100 ---
# ...
# test_batch (Avg. Loss 1.145, Accuracy 65.0): 100%|██████████| 313/313 [00:03<00:00, 79.94it/s]
# --- EPOCH 5/100 ---
# ...
# test_batch (Avg. Loss 1.205, Accuracy 68.0): 100%|██████████| 313/313 [00:03<00:00, 79.05it/s]
# --- EPOCH 6/100 ---
# ...
# test_batch (Avg. Loss 1.459, Accuracy 67.8): 100%|██████████| 313/313 [00:03<00:00, 78.99it/s]
# --- EPOCH 7/100 ---
# ...
# test_batch (Avg. Loss 1.723, Accuracy 67.3): 100%|██████████| 313/313 [00:03<00:00, 79.65it/s]
# --- EPOCH 8/100 ---
# ...
